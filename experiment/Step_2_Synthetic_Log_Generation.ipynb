# %% [markdown]
# ## ***Generating the Synthetic Eventlogs by Incorporating Overlapping Executions***
# #### *In this code, we introduce overlaps between two work items. To this end, we will use the preprocessed event logs generated in Step_1 of the experiment.*
# #### *As an example, we use the "Purchasing.xes" event log and incorporate overlaps with a multitasking level ratio of 0.9.*

# %%
# import the libraries
import numpy as np
import matplotlib.pyplot as plt
import time
import pm4py
from pm4py.objects.log.importer.xes import importer as xes_importer
import pytz
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt
from pm4py.objects.log.util import sorting
from pm4py.objects.log.exporter.xes import exporter as xes_exporter

# %%
log = xes_importer.apply('Purchasing_NMT.xes') 
log
# LOGS NO_MT:
# BPIC2012_NMT.xes
# BPIC2017_NMT.xes
# EDlog_NMT.xes
# Production_NMT.xes
# Purchasing_NMT.xes
# Out:
# parsing log, completed traces ::   0%|          | 0/608 [00:00<?, ?it/s]
# [{'attributes': {'concept:name': '1'}, 'events': [{'concept:name': 'Create Purchase Requisition', 'start:timestamp': datetime.datetime(2011, 1, 1, 0, 0, tzinfo=datetime.timezone.utc), 'time:timestamp': datetime.datetime(2011, 1, 1, 0, 37, tzinfo=datetime.timezone.utc), 'org:resource': 'Kim Passa', 'duration_seconds': 2220.0, 'duration_minutes': 37.0}, '..', {'concept:name': 'Pay invoice', 'start:timestamp': datetime.datetime(2011, 1, 4, 15, 22, tzinfo=datetime.timezone.utc), 'time:timestamp': datetime.datetime(2011, 1, 4, 15, 31, tzinfo=datetime.timezone.utc), 'org:resource': 'Pedro Alvares', 'duration_seconds': 540.0, 'duration_minutes': 9.0}]}, '....', {'attributes': {'concept:name': '1949'}, 'events': [{'concept:name': 'Create Purchase Requisition', 'start:timestamp': datetime.datetime(2011, 10, 13, 6, 27, tzinfo=datetime.timezone.utc), 'time:timestamp': datetime.datetime(2011, 10, 13, 7, 21, tzinfo=datetime.timezone.utc), 'org:resource': 'Tesca Lobes', 'duration_seconds': 3240.0, 'duration_minutes': 54.0}, '..', {'concept:name': 'Analyze Purchase Requisition', 'start:timestamp': datetime.datetime(2011, 10, 13, 17, 3, tzinfo=datetime.timezone.utc), 'time:timestamp': datetime.datetime(2011, 10, 13, 17, 9, tzinfo=datetime.timezone.utc), 'org:resource': 'Francis Odell', 'duration_seconds': 360.0, 'duration_minutes': 6.0}]}]

# %%
# Converting into the dataframe
df = pm4py.convert_to_dataframe(log)
df.head(20)
# Out:
#                               concept:name           start:timestamp  \
# 0              Create Purchase Requisition 2011-01-01 00:00:00+00:00
# 1   Create Request for Quotation Requester 2011-01-01 05:37:00+00:00
# 2            Analyze Request for Quotation 2011-01-01 06:41:00+00:00
# 3   Send Request for Quotation to Supplier 2011-01-01 11:43:00+00:00
# 4          Create Quotation comparison Map 2011-01-01 12:32:00+00:00
# 5         Analyze Quotation comparison Map 2011-01-01 22:44:00+00:00
# 6                       Choose best option 2011-01-01 23:13:00+00:00
# 7          Settle conditions with supplier 2011-01-02 01:22:00+00:00
# 8                    Create Purchase Order 2011-01-02 09:58:00+00:00
# 9                   Confirm Purchase Order 2011-01-02 14:09:00+00:00
# 10                  Deliver Goods Services 2011-01-02 20:49:00+00:00
# 11                  Release Purchase Order 2011-01-03 11:20:00+00:00
# 12      Approve Purchase Order for payment 2011-01-03 19:09:00+00:00
# 13                            Send invoice 2011-01-04 00:54:00+00:00
# 14              Release Supplier's Invoice 2011-01-04 15:08:00+00:00
# 15    Authorize Supplier's Invoice payment 2011-01-04 15:13:00+00:00
# 16                             Pay invoice 2011-01-04 15:22:00+00:00
# 17             Create Purchase Requisition 2011-01-01 00:16:00+00:00
# 18  Create Request for Quotation Requester 2011-01-01 08:16:00+00:00
# 19           Analyze Request for Quotation 2011-01-01 09:34:00+00:00
#
#               time:timestamp         org:resource  duration_seconds  \
# 0  2011-01-01 00:37:00+00:00            Kim Passa            2220.0
# 1  2011-01-01 05:45:00+00:00            Kim Passa             480.0
# 2  2011-01-01 06:55:00+00:00       Karel de Groot             840.0
# 3  2011-01-01 12:09:00+00:00       Karel de Groot            1560.0
# 4  2011-01-01 16:03:00+00:00   Magdalena Predutta           12660.0
# 5  2011-01-01 23:13:00+00:00  Immanuel Karagianni            1740.0
# 6  2011-01-01 23:13:00+00:00          Tesca Lobes               0.0
# 7  2011-01-02 09:20:00+00:00  Francois de Perrier           28680.0
# 8  2011-01-02 10:10:00+00:00       Karel de Groot             720.0
# 9  2011-01-02 14:43:00+00:00          Sean Manney            2040.0
# 10 2011-01-03 03:37:00+00:00          Sean Manney           24480.0
# 11 2011-01-03 11:21:00+00:00         Elvira Lores              60.0
# 12 2011-01-03 19:10:00+00:00       Karel de Groot              60.0
# 13 2011-01-04 00:54:00+00:00              Kiu Kan               0.0
# 14 2011-01-04 15:13:00+00:00      Karalda Nimwada             300.0
# 15 2011-01-04 15:13:00+00:00      Karalda Nimwada               0.0
# 16 2011-01-04 15:31:00+00:00        Pedro Alvares             540.0
# 17 2011-01-01 00:29:00+00:00  Immanuel Karagianni             780.0
# 18 2011-01-01 08:26:00+00:00       Alberto Duport             600.0
# 19 2011-01-01 09:38:00+00:00       Karel de Groot             240.0
#
#     duration_minutes case:concept:name
# 0               37.0                 1
# 1                8.0                 1
# 2               14.0                 1
# 3               26.0                 1
# 4              211.0                 1
# 5               29.0                 1
# 6                0.0                 1
# 7              478.0                 1
# 8               12.0                 1
# 9               34.0                 1
# 10             408.0                 1
# 11               1.0                 1
# 12               1.0                 1
# 13               0.0                 1
# 14               5.0                 1
# 15               0.0                 1
# 16               9.0                 1
# 17              13.0                 2
# 18              10.0                 2
# 19               4.0                 2

# %%
df_sorted = df.sort_values(['org:resource', 'start:timestamp']).copy()

#previous timestamps
df_sorted['prev_end'] = df_sorted.groupby('org:resource')['time:timestamp'].shift(1)
df_sorted['prev_start'] = df_sorted.groupby('org:resource')['start:timestamp'].shift(1)

#idle duration
df_sorted['idle_duration_min'] = ((df_sorted['start:timestamp'] - df_sorted['prev_end']).dt.total_seconds() / 60)

df_sorted['is_first'] = df_sorted['prev_end'].isna()

#transition type
df_sorted['transition_type'] = np.where(
    df_sorted['is_first'], 'first',
    np.where(df_sorted['idle_duration_min'] == 0, 'back_to_back', 
    np.where(df_sorted['idle_duration_min'] > 0, 'idle_gap', 'other'))
)

#keeping only idle_gap rows (positive idle)
idle_valid = df_sorted[df_sorted['transition_type'] == 'idle_gap']

overall_summary = pd.DataFrame({
    'Total Resources': [df['org:resource'].nunique()],
    'Total Work Items': [len(df)],
    'Total Transitions': [df_sorted['transition_type'].notna().sum()],
    'Back-to-Back Count': [(df_sorted['transition_type'] == 'back_to_back').sum()],
    'Idle Gap Transitions': [len(idle_valid)],
    'Avg Idle Duration': [idle_valid['idle_duration_min'].mean()],
    'Median Idle Duration': [idle_valid['idle_duration_min'].median()]
})

overall_summary['% Back-to-Back'] = (overall_summary['Back-to-Back Count'] / overall_summary['Total Transitions'] * 100).round(2)

overall_summary['% With Idle'] = (overall_summary['Idle Gap Transitions'] / overall_summary['Total Transitions'] * 100).round(2)

overall_summary
# Out:
#    Total Resources  Total Work Items  Total Transitions  Back-to-Back Count  \
# 0               27              9119               9119                2416
#
#    Idle Gap Transitions  Avg Idle Duration  Median Idle Duration  \
# 0                  6648        1485.637335                 578.5
#
#    % Back-to-Back  % With Idle
# 0           26.49         72.9

# %%
df['duration_minutes'] = (df['time:timestamp'] - df['start:timestamp']).dt.total_seconds() / 60.0

# %% [markdown]
# ### ***Main Part for Introducing Overlapping Executions***
# *To introduce overlap among the work items, we define specific criteria. To generate the synthetic log, the user needs to assign appropriate parameter values accordingly.*
#
# ***The variables used in this step are described as follows:***
# - `multitask_ratio` : represents the multitasking level ratio (the overall percentage of workitems that are executed in a multitasking fashion).
# - `idle_tolerance`  : indicates the maximum idle gap between two workitems if they are not executed back to back. We use the ***Median Idle Duration*** which is computed above.
# - `no_multitask_activities` : specifies the activities that should not be overlapped. In our experiment, the ED_Log contains some activity instances that must be executed individually.
# - `debug` : set to True to enable code debugging.

# %%
# MAIN PART TO INTRODUCE THE OVERLAP

def introduce_multitasking(
    df,
    multitask_ratio=0.9,           # Multitasking level ratio
    idle_tolerance=578.5,          # median of idle gap in minutes
    random_seed=42,
    #no_multitask_activities=None,  #for all logs: 'None', for ED_log: ['AUTONOMOUSLY TRIAGE', 'AMBULANCE TRIAGE', 'OBSERVATION', 'X-RAY REPORT', 'MRI REPORT'] 
    debug=False):                   #use 'True' if want to debug
    
    np.random.seed(random_seed)
    df = df.copy().sort_values(['org:resource', 'start:timestamp']).reset_index(drop=True)

    #keeping original timestamp of Groundtruth log
    df['old_start:timestamp'] = df['start:timestamp']
    df['old_end:timestamp'] = df['time:timestamp']
    df['overlap_flag'] = False

    used_indices = set()
    all_pairs = []

    # 1:Collect eligible pairs
    for res, group in df.groupby('org:resource'):
        indices = group.index.to_list()
        for i in range(len(indices) - 1):
            idx_A = indices[i]
            idx_B = indices[i + 1]

            # skip if already used
            if idx_A in used_indices or idx_B in used_indices:
                continue

            # skip pairs where either activity belongs to no-multitask list (RUN only if 'no_multitask_activities' is not 'None')
            # if (df.loc[idx_A, 'concept:name'] in no_multitask_activities or df.loc[idx_B, 'concept:name'] in no_multitask_activities):
            #     continue

            eA = df.loc[idx_A, 'time:timestamp']
            sB = df.loc[idx_B, 'start:timestamp']
            dA = df.loc[idx_A, 'duration_minutes']
            dB = df.loc[idx_B, 'duration_minutes']

            #skip the zero-duration workitems
            if dA == 0 or dB == 0:
                continue

            #compute idle duration in minutes
            idle_duration = (sB - eA).total_seconds() / 60.0

            #checking adjacency or within tolerance
            if 0 <= idle_duration <= idle_tolerance:
                all_pairs.append((idx_A, idx_B, idle_duration))

    # 2:Selecting random subset
    total_pairs = len(all_pairs)
    n_select = int(total_pairs * multitask_ratio)

    if n_select == 0:
        if debug:
            print("No eligible pairs for overlap.")
        return df

    selected_indices = np.random.choice(range(total_pairs), size=n_select, replace=False)
    selected_pairs = [all_pairs[i] for i in selected_indices]

    # 3:Apply overlaps
    for idx_A, idx_B, idle_duration in selected_pairs:
        # skip if used
        if idx_A in used_indices or idx_B in used_indices:
            continue

        sA = df.loc[idx_A, 'start:timestamp']
        eA = df.loc[idx_A, 'time:timestamp']
        sB = df.loc[idx_B, 'start:timestamp']
        eB = df.loc[idx_B, 'time:timestamp']
        dA = float(df.loc[idx_A, 'duration_minutes'])
        dB = float(df.loc[idx_B, 'duration_minutes'])

        #Removing the idle gap and writing it back to df
        if idle_duration > 0:
            sB_new = eA
            eB_new = sB_new + pd.to_timedelta(dB, unit='m')

            # write gap-removed timestamps back to dataframe so feasibility uses them
            df.loc[idx_B, 'start:timestamp'] = sB_new
            df.loc[idx_B, 'time:timestamp'] = eB_new

            #update local variables to the new values
            sB = sB_new
            eB = eB_new

            #marking the idle as removed(so extension dont include idle)
            idle_duration = 0

            if debug:
                print(f"[gap-removed] idx_A={idx_A}, idx_B={idx_B}, sB_old={df.loc[idx_B,'old_start:timestamp']}, sB_new={sB}")

        # Overlap attempts
        max_attempts = 20
        success = False

        for attempt in range(max_attempts):
            p = np.random.uniform(0.3, 0.7)
            q = 1 - p
            small_w = min(p, q)
            large_w = max(p, q)

            # del_A = % of dB, del_B = % of dA (below logic is just for so small_duration get large share in order to be 
            # visible or to show impact in overlap
            if dA >= dB:
                del_A = large_w * dB
                del_B = small_w * dA
            else:
                del_A = small_w * dB
                del_B = large_w * dA

            #extended durations
            extension_A = del_A
            extension_B = del_B

            new_end_A = eA + pd.to_timedelta(extension_A, unit='m')
            new_start_B = sB - pd.to_timedelta(extension_B, unit='m')

            # FEASIBILITY_CHECK (remain inside [sA, eB])
            #using the updated sB/eB (after gap removal) to ensure new_end_A and new_start_B fall in the window
            if (new_start_B >= sA) and (new_end_A <= eB):
                success = True
                if debug:
                    print(f"[attempt success] idx_A={idx_A}, idx_B={idx_B}, attempt={attempt+1}, del_A={del_A:.2f}, del_B={del_B:.2f}")
                break
            else:
                #debug toknow why failed
                if debug:
                    reason = []
                    if new_start_B < sA:
                        reason.append(f"new_start_B ({new_start_B}) < sA ({sA})")
                    if new_end_A > eB:
                        reason.append(f"new_end_A ({new_end_A}) > eB ({eB})")
                    if reason:
                        print(f"[attempt fail] idx_A={idx_A}, idx_B={idx_B}, attempt={attempt+1}, reason={' & '.join(reason)}")

        #If found a feasible overlap, apply the changes
        if success:
            # for A: extend its end
            df.loc[idx_A, 'time:timestamp'] = new_end_A
            # for B: move its start earlier
            df.loc[idx_B, 'start:timestamp'] = new_start_B

            #update the durations
            df.loc[idx_A, 'duration_minutes'] = (new_end_A - sA).total_seconds() / 60.0
            df.loc[idx_B, 'duration_minutes'] = (eB - new_start_B).total_seconds() / 60.0

            # flags and used indices
            df.loc[idx_A, 'overlap_flag'] = True
            df.loc[idx_B, 'overlap_flag'] = True
            used_indices.update([idx_A, idx_B])
        else:
            # not successful after attempts 
            if debug:
                print(f"[no feasible overlap] idx_A={idx_A}, idx_B={idx_B}")

    # Summary
    print(f"Total Eligible pairs(each pair has 2WI): {total_pairs}")
    print(f"Selected overlapping pairs(each pair has 2WI): {len(selected_pairs)}")
    print(f"From the selected overlapping pairs, the no. of work items that successfully used and involved in overlapping are: {len(used_indices)}")
    print(f"Idle tolerance used: {idle_tolerance} minutes")

    return df

out = introduce_multitasking(df)   
out.head(20)
# Out:
# Total Eligible pairs(each pair has 2WI): 4381
# Selected overlapping pairs(each pair has 2WI): 3942
# From the selected overlapping pairs, the no. of work items that successfully used and involved in overlapping are: 4608
# Idle tolerance used: 578.5 minutes
#                               concept:name  \
# 0   Create Request for Quotation Requester
# 1   Create Request for Quotation Requester
# 2              Create Purchase Requisition
# 3   Create Request for Quotation Requester
# 4              Create Purchase Requisition
# 5              Create Purchase Requisition
# 6              Create Purchase Requisition
# 7         Analyze Quotation comparison Map
# 8                       Choose best option
# 9    Amend Request for Quotation Requester
# 10        Analyze Quotation comparison Map
# 11   Amend Request for Quotation Requester
# 12   Amend Request for Quotation Requester
# 13   Amend Request for Quotation Requester
# 14   Amend Request for Quotation Requester
# 15  Create Request for Quotation Requester
# 16             Create Purchase Requisition
# 17                      Choose best option
# 18             Create Purchase Requisition
# 19        Analyze Quotation comparison Map
#
#                        start:timestamp                      time:timestamp  \
# 0            2011-01-01 08:16:00+00:00 2011-01-01 08:31:15.890822556+00:00
# 1  2011-01-01 08:20:02.992940430+00:00           2011-01-01 08:39:00+00:00
# 2            2011-01-02 05:31:00+00:00           2011-01-02 05:41:00+00:00
# 3            2011-01-03 04:02:00+00:00           2011-01-03 04:12:00+00:00
# 4            2011-01-03 17:22:00+00:00           2011-01-03 18:16:00+00:00
# 5            2011-01-04 12:33:00+00:00           2011-01-04 13:17:00+00:00
# 6            2011-01-05 10:01:00+00:00 2011-01-05 10:44:52.434444630+00:00
# 7  2011-01-05 10:23:21.053072250+00:00           2011-01-05 10:50:00+00:00
# 8            2011-01-05 12:25:00+00:00           2011-01-05 12:25:00+00:00
# 9            2011-01-05 19:14:00+00:00           2011-01-05 19:28:00+00:00
# 10           2011-01-06 17:25:00+00:00 2011-01-06 17:37:45.838753848+00:00
# 11 2011-01-06 17:29:45.838753848+00:00           2011-01-06 17:41:00+00:00
# 12           2011-01-06 21:09:00+00:00           2011-01-06 21:18:00+00:00
# 13           2011-01-06 22:11:00+00:00           2011-01-06 22:22:00+00:00
# 14           2011-01-07 05:59:00+00:00 2011-01-07 06:18:34.844571102+00:00
# 15 2011-01-07 06:07:40.869332820+00:00           2011-01-07 06:22:00+00:00
# 16           2011-01-08 03:01:00+00:00           2011-01-08 03:26:00+00:00
# 17           2011-01-09 02:16:00+00:00           2011-01-09 02:16:00+00:00
# 18           2011-01-09 07:20:00+00:00           2011-01-09 07:54:00+00:00
# 19           2011-01-09 08:23:00+00:00 2011-01-09 08:41:34.449488244+00:00
#
#       org:resource  duration_seconds  duration_minutes case:concept:name  \
# 0   Alberto Duport             600.0         15.264847                 2
# 1   Alberto Duport             780.0         18.950118                 6
# 2   Alberto Duport             600.0         10.000000                12
# 3   Alberto Duport             600.0         10.000000                17
# 4   Alberto Duport            3240.0         54.000000                27
# 5   Alberto Duport            2640.0         44.000000                30
# 6   Alberto Duport            1920.0         43.873907                41
# 7   Alberto Duport            1020.0         26.649115                27
# 8   Alberto Duport               0.0          0.000000                27
# 9   Alberto Duport             840.0         14.000000                30
# 10  Alberto Duport             480.0         12.763979                29
# 11  Alberto Duport             480.0         11.236021                26
# 12  Alberto Duport             540.0          9.000000                38
# 13  Alberto Duport             660.0         11.000000                30
# 14  Alberto Duport             840.0         19.580743                48
# 15  Alberto Duport             540.0         14.318844                53
# 16  Alberto Duport            1500.0         25.000000                58
# 17  Alberto Duport               0.0          0.000000                37
# 18  Alberto Duport            2040.0         34.000000                67
# 19  Alberto Duport            1080.0         18.574158                28
#
#          old_start:timestamp         old_end:timestamp  overlap_flag
# 0  2011-01-01 08:16:00+00:00 2011-01-01 08:26:00+00:00          True
# 1  2011-01-01 17:32:00+00:00 2011-01-01 17:45:00+00:00          True
# 2  2011-01-02 05:31:00+00:00 2011-01-02 05:41:00+00:00         False
# 3  2011-01-03 04:02:00+00:00 2011-01-03 04:12:00+00:00         False
# 4  2011-01-03 17:22:00+00:00 2011-01-03 18:16:00+00:00         False
# 5  2011-01-04 12:33:00+00:00 2011-01-04 13:17:00+00:00         False
# 6  2011-01-05 10:01:00+00:00 2011-01-05 10:33:00+00:00          True
# 7  2011-01-05 12:08:00+00:00 2011-01-05 12:25:00+00:00          True
# 8  2011-01-05 12:25:00+00:00 2011-01-05 12:25:00+00:00         False
# 9  2011-01-05 19:14:00+00:00 2011-01-05 19:28:00+00:00         False
# 10 2011-01-06 17:25:00+00:00 2011-01-06 17:33:00+00:00          True
# 11 2011-01-06 17:46:00+00:00 2011-01-06 17:54:00+00:00          True
# 12 2011-01-06 21:09:00+00:00 2011-01-06 21:18:00+00:00         False
# 13 2011-01-06 22:11:00+00:00 2011-01-06 22:22:00+00:00         False
# 14 2011-01-07 05:59:00+00:00 2011-01-07 06:13:00+00:00          True
# 15 2011-01-07 15:24:00+00:00 2011-01-07 15:33:00+00:00          True
# 16 2011-01-08 03:01:00+00:00 2011-01-08 03:26:00+00:00         False
# 17 2011-01-09 02:16:00+00:00 2011-01-09 02:16:00+00:00         False
# 18 2011-01-09 07:20:00+00:00 2011-01-09 07:54:00+00:00         False
# 19 2011-01-09 08:23:00+00:00 2011-01-09 08:41:00+00:00          True

# %%
print(len(out[out['overlap_flag']==True]))
print(len(out[out['overlap_flag']==False]))
# Out:
# 4608
# 4511

# %%
out['old_duration_minutes'] = (out['old_end:timestamp'] - out['old_start:timestamp']).dt.total_seconds() / 60.0

# %%
out['time:timestamp'] = out['time:timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S%z')
out['time:timestamp'] = pd.to_datetime(out['time:timestamp'], utc=True)

out['start:timestamp'] = out['start:timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S%z')
out['start:timestamp'] = pd.to_datetime(out['start:timestamp'], utc=True)

out['duration_minutes'] = (out['time:timestamp'] - out['start:timestamp']).dt.total_seconds() / 60.0
out.head(60)
# Out:
#                               concept:name           start:timestamp  \
# 0   Create Request for Quotation Requester 2011-01-01 08:16:00+00:00
# 1   Create Request for Quotation Requester 2011-01-01 08:20:02+00:00
# 2              Create Purchase Requisition 2011-01-02 05:31:00+00:00
# 3   Create Request for Quotation Requester 2011-01-03 04:02:00+00:00
# 4              Create Purchase Requisition 2011-01-03 17:22:00+00:00
# 5              Create Purchase Requisition 2011-01-04 12:33:00+00:00
# 6              Create Purchase Requisition 2011-01-05 10:01:00+00:00
# 7         Analyze Quotation comparison Map 2011-01-05 10:23:21+00:00
# 8                       Choose best option 2011-01-05 12:25:00+00:00
# 9    Amend Request for Quotation Requester 2011-01-05 19:14:00+00:00
# 10        Analyze Quotation comparison Map 2011-01-06 17:25:00+00:00
# 11   Amend Request for Quotation Requester 2011-01-06 17:29:45+00:00
# 12   Amend Request for Quotation Requester 2011-01-06 21:09:00+00:00
# 13   Amend Request for Quotation Requester 2011-01-06 22:11:00+00:00
# 14   Amend Request for Quotation Requester 2011-01-07 05:59:00+00:00
# 15  Create Request for Quotation Requester 2011-01-07 06:07:40+00:00
# 16             Create Purchase Requisition 2011-01-08 03:01:00+00:00
# 17                      Choose best option 2011-01-09 02:16:00+00:00
# 18             Create Purchase Requisition 2011-01-09 07:20:00+00:00
# 19        Analyze Quotation comparison Map 2011-01-09 08:23:00+00:00
# 20                  Release Purchase Order 2011-01-09 08:33:20+00:00
# 21   Amend Request for Quotation Requester 2011-01-09 21:08:00+00:00
# 22             Create Purchase Requisition 2011-01-10 17:53:00+00:00
# 23             Create Purchase Requisition 2011-01-10 17:59:03+00:00
# 24                  Release Purchase Order 2011-01-11 00:42:00+00:00
# 25  Create Request for Quotation Requester 2011-01-11 00:42:23+00:00
# 26             Create Purchase Requisition 2011-01-11 08:43:00+00:00
# 27                  Release Purchase Order 2011-01-11 19:07:00+00:00
# 28   Amend Request for Quotation Requester 2011-01-12 06:33:00+00:00
# 29   Amend Request for Quotation Requester 2011-01-12 06:42:18+00:00
# 30                  Release Purchase Order 2011-01-12 18:44:00+00:00
# 31        Analyze Quotation comparison Map 2011-01-12 18:44:24+00:00
# 32                      Choose best option 2011-01-13 04:42:00+00:00
# 33   Amend Request for Quotation Requester 2011-01-13 09:35:00+00:00
# 34             Create Purchase Requisition 2011-01-13 13:17:00+00:00
# 35                  Release Purchase Order 2011-01-13 13:22:52+00:00
# 36                  Release Purchase Order 2011-01-14 09:40:00+00:00
# 37                      Choose best option 2011-01-14 14:51:00+00:00
# 38   Amend Request for Quotation Requester 2011-01-15 04:48:00+00:00
# 39        Analyze Quotation comparison Map 2011-01-15 16:54:00+00:00
# 40        Analyze Quotation comparison Map 2011-01-16 09:57:00+00:00
# 41   Amend Request for Quotation Requester 2011-01-16 10:00:17+00:00
# 42        Analyze Quotation comparison Map 2011-01-17 15:20:00+00:00
# 43                      Choose best option 2011-01-17 15:34:00+00:00
# 44   Amend Request for Quotation Requester 2011-01-17 17:02:00+00:00
# 45             Create Purchase Requisition 2011-01-17 17:06:20+00:00
# 46  Create Request for Quotation Requester 2011-01-18 00:38:00+00:00
# 47             Create Purchase Requisition 2011-01-18 00:42:19+00:00
# 48        Analyze Quotation comparison Map 2011-01-19 12:34:00+00:00
# 49                      Choose best option 2011-01-19 13:49:00+00:00
# 50        Analyze Quotation comparison Map 2011-01-19 23:37:00+00:00
# 51                      Choose best option 2011-01-21 10:50:00+00:00
# 52                      Choose best option 2011-01-22 06:35:00+00:00
# 53                  Release Purchase Order 2011-01-22 14:08:00+00:00
# 54        Analyze Quotation comparison Map 2011-01-23 05:30:00+00:00
# 55                      Choose best option 2011-01-23 18:48:00+00:00
# 56        Analyze Quotation comparison Map 2011-01-24 04:31:00+00:00
# 57                      Choose best option 2011-01-24 04:48:00+00:00
# 58                  Release Purchase Order 2011-01-24 14:18:00+00:00
# 59             Create Purchase Requisition 2011-01-24 16:54:00+00:00
#
#               time:timestamp    org:resource  duration_seconds  \
# 0  2011-01-01 08:31:15+00:00  Alberto Duport             600.0
# 1  2011-01-01 08:39:00+00:00  Alberto Duport             780.0
# 2  2011-01-02 05:41:00+00:00  Alberto Duport             600.0
# 3  2011-01-03 04:12:00+00:00  Alberto Duport             600.0
# 4  2011-01-03 18:16:00+00:00  Alberto Duport            3240.0
# 5  2011-01-04 13:17:00+00:00  Alberto Duport            2640.0
# 6  2011-01-05 10:44:52+00:00  Alberto Duport            1920.0
# 7  2011-01-05 10:50:00+00:00  Alberto Duport            1020.0
# 8  2011-01-05 12:25:00+00:00  Alberto Duport               0.0
# 9  2011-01-05 19:28:00+00:00  Alberto Duport             840.0
# 10 2011-01-06 17:37:45+00:00  Alberto Duport             480.0
# 11 2011-01-06 17:41:00+00:00  Alberto Duport             480.0
# 12 2011-01-06 21:18:00+00:00  Alberto Duport             540.0
# 13 2011-01-06 22:22:00+00:00  Alberto Duport             660.0
# 14 2011-01-07 06:18:34+00:00  Alberto Duport             840.0
# 15 2011-01-07 06:22:00+00:00  Alberto Duport             540.0
# 16 2011-01-08 03:26:00+00:00  Alberto Duport            1500.0
# 17 2011-01-09 02:16:00+00:00  Alberto Duport               0.0
# 18 2011-01-09 07:54:00+00:00  Alberto Duport            2040.0
# 19 2011-01-09 08:41:34+00:00  Alberto Duport            1080.0
# 20 2011-01-09 08:42:00+00:00  Alberto Duport              60.0
# 21 2011-01-09 21:16:00+00:00  Alberto Duport             480.0
# 22 2011-01-10 18:22:50+00:00  Alberto Duport            1140.0
# 23 2011-01-10 18:46:00+00:00  Alberto Duport            2040.0
# 24 2011-01-11 00:46:34+00:00  Alberto Duport              60.0
# 25 2011-01-11 00:52:00+00:00  Alberto Duport             540.0
# 26 2011-01-11 09:13:00+00:00  Alberto Duport            1800.0
# 27 2011-01-11 19:08:00+00:00  Alberto Duport              60.0
# 28 2011-01-12 06:53:38+00:00  Alberto Duport             840.0
# 29 2011-01-12 06:57:00+00:00  Alberto Duport             600.0
# 30 2011-01-12 18:55:24+00:00  Alberto Duport              60.0
# 31 2011-01-12 19:11:00+00:00  Alberto Duport            1560.0
# 32 2011-01-13 04:42:00+00:00  Alberto Duport               0.0
# 33 2011-01-13 09:41:00+00:00  Alberto Duport             360.0
# 34 2011-01-13 13:26:39+00:00  Alberto Duport             540.0
# 35 2011-01-13 13:27:00+00:00  Alberto Duport              60.0
# 36 2011-01-14 09:41:00+00:00  Alberto Duport              60.0
# 37 2011-01-14 14:51:00+00:00  Alberto Duport               0.0
# 38 2011-01-15 04:55:00+00:00  Alberto Duport             420.0
# 39 2011-01-15 17:14:00+00:00  Alberto Duport            1200.0
# 40 2011-01-16 10:09:39+00:00  Alberto Duport             540.0
# 41 2011-01-16 10:16:00+00:00  Alberto Duport             600.0
# 42 2011-01-17 15:34:00+00:00  Alberto Duport             840.0
# 43 2011-01-17 15:34:00+00:00  Alberto Duport               0.0
# 44 2011-01-17 17:22:29+00:00  Alberto Duport             660.0
# 45 2011-01-17 17:37:00+00:00  Alberto Duport            1440.0
# 46 2011-01-18 01:07:29+00:00  Alberto Duport             600.0
# 47 2011-01-18 01:33:00+00:00  Alberto Duport            2700.0
# 48 2011-01-19 12:43:00+00:00  Alberto Duport             540.0
# 49 2011-01-19 13:49:00+00:00  Alberto Duport               0.0
# 50 2011-01-19 23:44:00+00:00  Alberto Duport             420.0
# 51 2011-01-21 10:50:00+00:00  Alberto Duport               0.0
# 52 2011-01-22 06:35:00+00:00  Alberto Duport               0.0
# 53 2011-01-22 14:09:00+00:00  Alberto Duport              60.0
# 54 2011-01-23 05:48:00+00:00  Alberto Duport            1080.0
# 55 2011-01-23 18:48:00+00:00  Alberto Duport               0.0
# 56 2011-01-24 04:48:00+00:00  Alberto Duport            1020.0
# 57 2011-01-24 04:48:00+00:00  Alberto Duport               0.0
# 58 2011-01-24 14:19:00+00:00  Alberto Duport              60.0
# 59 2011-01-24 17:48:52+00:00  Alberto Duport            2460.0
#
#     duration_minutes case:concept:name       old_start:timestamp  \
# 0          15.250000                 2 2011-01-01 08:16:00+00:00
# 1          18.966667                 6 2011-01-01 17:32:00+00:00
# 2          10.000000                12 2011-01-02 05:31:00+00:00
# 3          10.000000                17 2011-01-03 04:02:00+00:00
# 4          54.000000                27 2011-01-03 17:22:00+00:00
# 5          44.000000                30 2011-01-04 12:33:00+00:00
# 6          43.866667                41 2011-01-05 10:01:00+00:00
# 7          26.650000                27 2011-01-05 12:08:00+00:00
# 8           0.000000                27 2011-01-05 12:25:00+00:00
# 9          14.000000                30 2011-01-05 19:14:00+00:00
# 10         12.750000                29 2011-01-06 17:25:00+00:00
# 11         11.250000                26 2011-01-06 17:46:00+00:00
# 12          9.000000                38 2011-01-06 21:09:00+00:00
# 13         11.000000                30 2011-01-06 22:11:00+00:00
# 14         19.566667                48 2011-01-07 05:59:00+00:00
# 15         14.333333                53 2011-01-07 15:24:00+00:00
# 16         25.000000                58 2011-01-08 03:01:00+00:00
# 17          0.000000                37 2011-01-09 02:16:00+00:00
# 18         34.000000                67 2011-01-09 07:20:00+00:00
# 19         18.566667                28 2011-01-09 08:23:00+00:00
# 20          8.666667                24 2011-01-09 13:28:00+00:00
# 21          8.000000                64 2011-01-09 21:08:00+00:00
# 22         29.833333                81 2011-01-10 17:53:00+00:00
# 23         46.950000                82 2011-01-10 20:09:00+00:00
# 24          4.566667                29 2011-01-11 00:42:00+00:00
# 25          9.616667                82 2011-01-11 03:53:00+00:00
# 26         30.000000                85 2011-01-11 08:43:00+00:00
# 27          1.000000                28 2011-01-11 19:07:00+00:00
# 28         20.633333                64 2011-01-12 06:33:00+00:00
# 29         14.700000                66 2011-01-12 06:55:00+00:00
# 30         11.400000                44 2011-01-12 18:44:00+00:00
# 31         26.600000                79 2011-01-12 23:37:00+00:00
# 32          0.000000                68 2011-01-13 04:42:00+00:00
# 33          6.000000                70 2011-01-13 09:35:00+00:00
# 34          9.650000               102 2011-01-13 13:17:00+00:00
# 35          4.133333                38 2011-01-13 15:15:00+00:00
# 36          1.000000                39 2011-01-14 09:40:00+00:00
# 37          0.000000                81 2011-01-14 14:51:00+00:00
# 38          7.000000                92 2011-01-15 04:48:00+00:00
# 39         20.000000                71 2011-01-15 16:54:00+00:00
# 40         12.650000                80 2011-01-16 09:57:00+00:00
# 41         15.716667               112 2011-01-16 15:19:00+00:00
# 42         14.000000               117 2011-01-17 15:20:00+00:00
# 43          0.000000               117 2011-01-17 15:34:00+00:00
# 44         20.483333               128 2011-01-17 17:02:00+00:00
# 45         30.666667               134 2011-01-17 21:00:00+00:00
# 46         29.483333               135 2011-01-18 00:38:00+00:00
# 47         50.683333               137 2011-01-18 04:33:00+00:00
# 48          9.000000               119 2011-01-19 12:34:00+00:00
# 49          0.000000               101 2011-01-19 13:49:00+00:00
# 50          7.000000               107 2011-01-19 23:37:00+00:00
# 51          0.000000               122 2011-01-21 10:50:00+00:00
# 52          0.000000               141 2011-01-22 06:35:00+00:00
# 53          1.000000                78 2011-01-22 14:08:00+00:00
# 54         18.000000               146 2011-01-23 05:30:00+00:00
# 55          0.000000               142 2011-01-23 18:48:00+00:00
# 56         17.000000               153 2011-01-24 04:31:00+00:00
# 57          0.000000               153 2011-01-24 04:48:00+00:00
# 58          1.000000               110 2011-01-24 14:18:00+00:00
# 59         54.866667               179 2011-01-24 16:54:00+00:00
#
#            old_end:timestamp  overlap_flag  old_duration_minutes
# 0  2011-01-01 08:26:00+00:00          True                  10.0
# 1  2011-01-01 17:45:00+00:00          True                  13.0
# 2  2011-01-02 05:41:00+00:00         False                  10.0
# 3  2011-01-03 04:12:00+00:00         False                  10.0
# 4  2011-01-03 18:16:00+00:00         False                  54.0
# 5  2011-01-04 13:17:00+00:00         False                  44.0
# 6  2011-01-05 10:33:00+00:00          True                  32.0
# 7  2011-01-05 12:25:00+00:00          True                  17.0
# 8  2011-01-05 12:25:00+00:00         False                   0.0
# 9  2011-01-05 19:28:00+00:00         False                  14.0
# 10 2011-01-06 17:33:00+00:00          True                   8.0
# 11 2011-01-06 17:54:00+00:00          True                   8.0
# 12 2011-01-06 21:18:00+00:00         False                   9.0
# 13 2011-01-06 22:22:00+00:00         False                  11.0
# 14 2011-01-07 06:13:00+00:00          True                  14.0
# 15 2011-01-07 15:33:00+00:00          True                   9.0
# 16 2011-01-08 03:26:00+00:00         False                  25.0
# 17 2011-01-09 02:16:00+00:00         False                   0.0
# 18 2011-01-09 07:54:00+00:00         False                  34.0
# 19 2011-01-09 08:41:00+00:00          True                  18.0
# 20 2011-01-09 13:29:00+00:00          True                   1.0
# 21 2011-01-09 21:16:00+00:00         False                   8.0
# 22 2011-01-10 18:12:00+00:00          True                  19.0
# 23 2011-01-10 20:43:00+00:00          True                  34.0
# 24 2011-01-11 00:43:00+00:00          True                   1.0
# 25 2011-01-11 04:02:00+00:00          True                   9.0
# 26 2011-01-11 09:13:00+00:00         False                  30.0
# 27 2011-01-11 19:08:00+00:00         False                   1.0
# 28 2011-01-12 06:47:00+00:00          True                  14.0
# 29 2011-01-12 07:05:00+00:00          True                  10.0
# 30 2011-01-12 18:45:00+00:00          True                   1.0
# 31 2011-01-13 00:03:00+00:00          True                  26.0
# 32 2011-01-13 04:42:00+00:00         False                   0.0
# 33 2011-01-13 09:41:00+00:00         False                   6.0
# 34 2011-01-13 13:26:00+00:00          True                   9.0
# 35 2011-01-13 15:16:00+00:00          True                   1.0
# 36 2011-01-14 09:41:00+00:00         False                   1.0
# 37 2011-01-14 14:51:00+00:00         False                   0.0
# 38 2011-01-15 04:55:00+00:00         False                   7.0
# 39 2011-01-15 17:14:00+00:00         False                  20.0
# 40 2011-01-16 10:06:00+00:00          True                   9.0
# 41 2011-01-16 15:29:00+00:00          True                  10.0
# 42 2011-01-17 15:34:00+00:00         False                  14.0
# 43 2011-01-17 15:34:00+00:00         False                   0.0
# 44 2011-01-17 17:13:00+00:00          True                  11.0
# 45 2011-01-17 21:24:00+00:00          True                  24.0
# 46 2011-01-18 00:48:00+00:00          True                  10.0
# 47 2011-01-18 05:18:00+00:00          True                  45.0
# 48 2011-01-19 12:43:00+00:00         False                   9.0
# 49 2011-01-19 13:49:00+00:00         False                   0.0
# 50 2011-01-19 23:44:00+00:00         False                   7.0
# 51 2011-01-21 10:50:00+00:00         False                   0.0
# 52 2011-01-22 06:35:00+00:00         False                   0.0
# 53 2011-01-22 14:09:00+00:00         False                   1.0
# 54 2011-01-23 05:48:00+00:00         False                  18.0
# 55 2011-01-23 18:48:00+00:00         False                   0.0
# 56 2011-01-24 04:48:00+00:00         False                  17.0
# 57 2011-01-24 04:48:00+00:00         False                   0.0
# 58 2011-01-24 14:19:00+00:00         False                   1.0
# 59 2011-01-24 17:35:00+00:00          True                  41.0

# %% [markdown]
# ***The final genertated synthetic log contains the following attributes:***
# - `case:concept:name` : case_id.
# - `concept:name` : activity.
# - `org:resource`: resource.
# - `start:timestamp` : new start time of the workitem after introducng overlapping execution.
# - `time:timestamp` : new end time of the workitem after  introducng overlapping execution.
# - `duration_minutes` : new duration of the workitem (time:timestamp - start:timestamp). In subsequent steps of the experiment we call it as ***'MT'(Multitasking)***.
# - `old_start:timestamp` : start time of the workitems when there were no multitasking executions (before introducing overlaps),
# - `old_end:timestamp` : end time of the workitems when there were no multitasking executions (before introducing overlaps).
# - `old_duration_minutes` : duration of the workitems when there were no multitasking executions. We treat it as ***Ground-truth (GT)*** in our subsequent experiment steps.
# - `overlap_flag` : indicates whether workitem used or not for introducing overlaps.

# %%
out = out[['case:concept:name', 'concept:name', 'org:resource', 'start:timestamp', 'time:timestamp', 'duration_minutes', 
                       'old_start:timestamp', 'old_end:timestamp', 'old_duration_minutes', 'overlap_flag']]
out.head(60)
# Out:
#    case:concept:name                            concept:name    org:resource  \
# 0                  2  Create Request for Quotation Requester  Alberto Duport
# 1                  6  Create Request for Quotation Requester  Alberto Duport
# 2                 12             Create Purchase Requisition  Alberto Duport
# 3                 17  Create Request for Quotation Requester  Alberto Duport
# 4                 27             Create Purchase Requisition  Alberto Duport
# 5                 30             Create Purchase Requisition  Alberto Duport
# 6                 41             Create Purchase Requisition  Alberto Duport
# 7                 27        Analyze Quotation comparison Map  Alberto Duport
# 8                 27                      Choose best option  Alberto Duport
# 9                 30   Amend Request for Quotation Requester  Alberto Duport
# 10                29        Analyze Quotation comparison Map  Alberto Duport
# 11                26   Amend Request for Quotation Requester  Alberto Duport
# 12                38   Amend Request for Quotation Requester  Alberto Duport
# 13                30   Amend Request for Quotation Requester  Alberto Duport
# 14                48   Amend Request for Quotation Requester  Alberto Duport
# 15                53  Create Request for Quotation Requester  Alberto Duport
# 16                58             Create Purchase Requisition  Alberto Duport
# 17                37                      Choose best option  Alberto Duport
# 18                67             Create Purchase Requisition  Alberto Duport
# 19                28        Analyze Quotation comparison Map  Alberto Duport
# 20                24                  Release Purchase Order  Alberto Duport
# 21                64   Amend Request for Quotation Requester  Alberto Duport
# 22                81             Create Purchase Requisition  Alberto Duport
# 23                82             Create Purchase Requisition  Alberto Duport
# 24                29                  Release Purchase Order  Alberto Duport
# 25                82  Create Request for Quotation Requester  Alberto Duport
# 26                85             Create Purchase Requisition  Alberto Duport
# 27                28                  Release Purchase Order  Alberto Duport
# 28                64   Amend Request for Quotation Requester  Alberto Duport
# 29                66   Amend Request for Quotation Requester  Alberto Duport
# 30                44                  Release Purchase Order  Alberto Duport
# 31                79        Analyze Quotation comparison Map  Alberto Duport
# 32                68                      Choose best option  Alberto Duport
# 33                70   Amend Request for Quotation Requester  Alberto Duport
# 34               102             Create Purchase Requisition  Alberto Duport
# 35                38                  Release Purchase Order  Alberto Duport
# 36                39                  Release Purchase Order  Alberto Duport
# 37                81                      Choose best option  Alberto Duport
# 38                92   Amend Request for Quotation Requester  Alberto Duport
# 39                71        Analyze Quotation comparison Map  Alberto Duport
# 40                80        Analyze Quotation comparison Map  Alberto Duport
# 41               112   Amend Request for Quotation Requester  Alberto Duport
# 42               117        Analyze Quotation comparison Map  Alberto Duport
# 43               117                      Choose best option  Alberto Duport
# 44               128   Amend Request for Quotation Requester  Alberto Duport
# 45               134             Create Purchase Requisition  Alberto Duport
# 46               135  Create Request for Quotation Requester  Alberto Duport
# 47               137             Create Purchase Requisition  Alberto Duport
# 48               119        Analyze Quotation comparison Map  Alberto Duport
# 49               101                      Choose best option  Alberto Duport
# 50               107        Analyze Quotation comparison Map  Alberto Duport
# 51               122                      Choose best option  Alberto Duport
# 52               141                      Choose best option  Alberto Duport
# 53                78                  Release Purchase Order  Alberto Duport
# 54               146        Analyze Quotation comparison Map  Alberto Duport
# 55               142                      Choose best option  Alberto Duport
# 56               153        Analyze Quotation comparison Map  Alberto Duport
# 57               153                      Choose best option  Alberto Duport
# 58               110                  Release Purchase Order  Alberto Duport
# 59               179             Create Purchase Requisition  Alberto Duport
#
#              start:timestamp            time:timestamp  duration_minutes  \
# 0  2011-01-01 08:16:00+00:00 2011-01-01 08:31:15+00:00         15.250000
# 1  2011-01-01 08:20:02+00:00 2011-01-01 08:39:00+00:00         18.966667
# 2  2011-01-02 05:31:00+00:00 2011-01-02 05:41:00+00:00         10.000000
# 3  2011-01-03 04:02:00+00:00 2011-01-03 04:12:00+00:00         10.000000
# 4  2011-01-03 17:22:00+00:00 2011-01-03 18:16:00+00:00         54.000000
# 5  2011-01-04 12:33:00+00:00 2011-01-04 13:17:00+00:00         44.000000
# 6  2011-01-05 10:01:00+00:00 2011-01-05 10:44:52+00:00         43.866667
# 7  2011-01-05 10:23:21+00:00 2011-01-05 10:50:00+00:00         26.650000
# 8  2011-01-05 12:25:00+00:00 2011-01-05 12:25:00+00:00          0.000000
# 9  2011-01-05 19:14:00+00:00 2011-01-05 19:28:00+00:00         14.000000
# 10 2011-01-06 17:25:00+00:00 2011-01-06 17:37:45+00:00         12.750000
# 11 2011-01-06 17:29:45+00:00 2011-01-06 17:41:00+00:00         11.250000
# 12 2011-01-06 21:09:00+00:00 2011-01-06 21:18:00+00:00          9.000000
# 13 2011-01-06 22:11:00+00:00 2011-01-06 22:22:00+00:00         11.000000
# 14 2011-01-07 05:59:00+00:00 2011-01-07 06:18:34+00:00         19.566667
# 15 2011-01-07 06:07:40+00:00 2011-01-07 06:22:00+00:00         14.333333
# 16 2011-01-08 03:01:00+00:00 2011-01-08 03:26:00+00:00         25.000000
# 17 2011-01-09 02:16:00+00:00 2011-01-09 02:16:00+00:00          0.000000
# 18 2011-01-09 07:20:00+00:00 2011-01-09 07:54:00+00:00         34.000000
# 19 2011-01-09 08:23:00+00:00 2011-01-09 08:41:34+00:00         18.566667
# 20 2011-01-09 08:33:20+00:00 2011-01-09 08:42:00+00:00          8.666667
# 21 2011-01-09 21:08:00+00:00 2011-01-09 21:16:00+00:00          8.000000
# 22 2011-01-10 17:53:00+00:00 2011-01-10 18:22:50+00:00         29.833333
# 23 2011-01-10 17:59:03+00:00 2011-01-10 18:46:00+00:00         46.950000
# 24 2011-01-11 00:42:00+00:00 2011-01-11 00:46:34+00:00          4.566667
# 25 2011-01-11 00:42:23+00:00 2011-01-11 00:52:00+00:00          9.616667
# 26 2011-01-11 08:43:00+00:00 2011-01-11 09:13:00+00:00         30.000000
# 27 2011-01-11 19:07:00+00:00 2011-01-11 19:08:00+00:00          1.000000
# 28 2011-01-12 06:33:00+00:00 2011-01-12 06:53:38+00:00         20.633333
# 29 2011-01-12 06:42:18+00:00 2011-01-12 06:57:00+00:00         14.700000
# 30 2011-01-12 18:44:00+00:00 2011-01-12 18:55:24+00:00         11.400000
# 31 2011-01-12 18:44:24+00:00 2011-01-12 19:11:00+00:00         26.600000
# 32 2011-01-13 04:42:00+00:00 2011-01-13 04:42:00+00:00          0.000000
# 33 2011-01-13 09:35:00+00:00 2011-01-13 09:41:00+00:00          6.000000
# 34 2011-01-13 13:17:00+00:00 2011-01-13 13:26:39+00:00          9.650000
# 35 2011-01-13 13:22:52+00:00 2011-01-13 13:27:00+00:00          4.133333
# 36 2011-01-14 09:40:00+00:00 2011-01-14 09:41:00+00:00          1.000000
# 37 2011-01-14 14:51:00+00:00 2011-01-14 14:51:00+00:00          0.000000
# 38 2011-01-15 04:48:00+00:00 2011-01-15 04:55:00+00:00          7.000000
# 39 2011-01-15 16:54:00+00:00 2011-01-15 17:14:00+00:00         20.000000
# 40 2011-01-16 09:57:00+00:00 2011-01-16 10:09:39+00:00         12.650000
# 41 2011-01-16 10:00:17+00:00 2011-01-16 10:16:00+00:00         15.716667
# 42 2011-01-17 15:20:00+00:00 2011-01-17 15:34:00+00:00         14.000000
# 43 2011-01-17 15:34:00+00:00 2011-01-17 15:34:00+00:00          0.000000
# 44 2011-01-17 17:02:00+00:00 2011-01-17 17:22:29+00:00         20.483333
# 45 2011-01-17 17:06:20+00:00 2011-01-17 17:37:00+00:00         30.666667
# 46 2011-01-18 00:38:00+00:00 2011-01-18 01:07:29+00:00         29.483333
# 47 2011-01-18 00:42:19+00:00 2011-01-18 01:33:00+00:00         50.683333
# 48 2011-01-19 12:34:00+00:00 2011-01-19 12:43:00+00:00          9.000000
# 49 2011-01-19 13:49:00+00:00 2011-01-19 13:49:00+00:00          0.000000
# 50 2011-01-19 23:37:00+00:00 2011-01-19 23:44:00+00:00          7.000000
# 51 2011-01-21 10:50:00+00:00 2011-01-21 10:50:00+00:00          0.000000
# 52 2011-01-22 06:35:00+00:00 2011-01-22 06:35:00+00:00          0.000000
# 53 2011-01-22 14:08:00+00:00 2011-01-22 14:09:00+00:00          1.000000
# 54 2011-01-23 05:30:00+00:00 2011-01-23 05:48:00+00:00         18.000000
# 55 2011-01-23 18:48:00+00:00 2011-01-23 18:48:00+00:00          0.000000
# 56 2011-01-24 04:31:00+00:00 2011-01-24 04:48:00+00:00         17.000000
# 57 2011-01-24 04:48:00+00:00 2011-01-24 04:48:00+00:00          0.000000
# 58 2011-01-24 14:18:00+00:00 2011-01-24 14:19:00+00:00          1.000000
# 59 2011-01-24 16:54:00+00:00 2011-01-24 17:48:52+00:00         54.866667
#
#          old_start:timestamp         old_end:timestamp  old_duration_minutes  \
# 0  2011-01-01 08:16:00+00:00 2011-01-01 08:26:00+00:00                  10.0
# 1  2011-01-01 17:32:00+00:00 2011-01-01 17:45:00+00:00                  13.0
# 2  2011-01-02 05:31:00+00:00 2011-01-02 05:41:00+00:00                  10.0
# 3  2011-01-03 04:02:00+00:00 2011-01-03 04:12:00+00:00                  10.0
# 4  2011-01-03 17:22:00+00:00 2011-01-03 18:16:00+00:00                  54.0
# 5  2011-01-04 12:33:00+00:00 2011-01-04 13:17:00+00:00                  44.0
# 6  2011-01-05 10:01:00+00:00 2011-01-05 10:33:00+00:00                  32.0
# 7  2011-01-05 12:08:00+00:00 2011-01-05 12:25:00+00:00                  17.0
# 8  2011-01-05 12:25:00+00:00 2011-01-05 12:25:00+00:00                   0.0
# 9  2011-01-05 19:14:00+00:00 2011-01-05 19:28:00+00:00                  14.0
# 10 2011-01-06 17:25:00+00:00 2011-01-06 17:33:00+00:00                   8.0
# 11 2011-01-06 17:46:00+00:00 2011-01-06 17:54:00+00:00                   8.0
# 12 2011-01-06 21:09:00+00:00 2011-01-06 21:18:00+00:00                   9.0
# 13 2011-01-06 22:11:00+00:00 2011-01-06 22:22:00+00:00                  11.0
# 14 2011-01-07 05:59:00+00:00 2011-01-07 06:13:00+00:00                  14.0
# 15 2011-01-07 15:24:00+00:00 2011-01-07 15:33:00+00:00                   9.0
# 16 2011-01-08 03:01:00+00:00 2011-01-08 03:26:00+00:00                  25.0
# 17 2011-01-09 02:16:00+00:00 2011-01-09 02:16:00+00:00                   0.0
# 18 2011-01-09 07:20:00+00:00 2011-01-09 07:54:00+00:00                  34.0
# 19 2011-01-09 08:23:00+00:00 2011-01-09 08:41:00+00:00                  18.0
# 20 2011-01-09 13:28:00+00:00 2011-01-09 13:29:00+00:00                   1.0
# 21 2011-01-09 21:08:00+00:00 2011-01-09 21:16:00+00:00                   8.0
# 22 2011-01-10 17:53:00+00:00 2011-01-10 18:12:00+00:00                  19.0
# 23 2011-01-10 20:09:00+00:00 2011-01-10 20:43:00+00:00                  34.0
# 24 2011-01-11 00:42:00+00:00 2011-01-11 00:43:00+00:00                   1.0
# 25 2011-01-11 03:53:00+00:00 2011-01-11 04:02:00+00:00                   9.0
# 26 2011-01-11 08:43:00+00:00 2011-01-11 09:13:00+00:00                  30.0
# 27 2011-01-11 19:07:00+00:00 2011-01-11 19:08:00+00:00                   1.0
# 28 2011-01-12 06:33:00+00:00 2011-01-12 06:47:00+00:00                  14.0
# 29 2011-01-12 06:55:00+00:00 2011-01-12 07:05:00+00:00                  10.0
# 30 2011-01-12 18:44:00+00:00 2011-01-12 18:45:00+00:00                   1.0
# 31 2011-01-12 23:37:00+00:00 2011-01-13 00:03:00+00:00                  26.0
# 32 2011-01-13 04:42:00+00:00 2011-01-13 04:42:00+00:00                   0.0
# 33 2011-01-13 09:35:00+00:00 2011-01-13 09:41:00+00:00                   6.0
# 34 2011-01-13 13:17:00+00:00 2011-01-13 13:26:00+00:00                   9.0
# 35 2011-01-13 15:15:00+00:00 2011-01-13 15:16:00+00:00                   1.0
# 36 2011-01-14 09:40:00+00:00 2011-01-14 09:41:00+00:00                   1.0
# 37 2011-01-14 14:51:00+00:00 2011-01-14 14:51:00+00:00                   0.0
# 38 2011-01-15 04:48:00+00:00 2011-01-15 04:55:00+00:00                   7.0
# 39 2011-01-15 16:54:00+00:00 2011-01-15 17:14:00+00:00                  20.0
# 40 2011-01-16 09:57:00+00:00 2011-01-16 10:06:00+00:00                   9.0
# 41 2011-01-16 15:19:00+00:00 2011-01-16 15:29:00+00:00                  10.0
# 42 2011-01-17 15:20:00+00:00 2011-01-17 15:34:00+00:00                  14.0
# 43 2011-01-17 15:34:00+00:00 2011-01-17 15:34:00+00:00                   0.0
# 44 2011-01-17 17:02:00+00:00 2011-01-17 17:13:00+00:00                  11.0
# 45 2011-01-17 21:00:00+00:00 2011-01-17 21:24:00+00:00                  24.0
# 46 2011-01-18 00:38:00+00:00 2011-01-18 00:48:00+00:00                  10.0
# 47 2011-01-18 04:33:00+00:00 2011-01-18 05:18:00+00:00                  45.0
# 48 2011-01-19 12:34:00+00:00 2011-01-19 12:43:00+00:00                   9.0
# 49 2011-01-19 13:49:00+00:00 2011-01-19 13:49:00+00:00                   0.0
# 50 2011-01-19 23:37:00+00:00 2011-01-19 23:44:00+00:00                   7.0
# 51 2011-01-21 10:50:00+00:00 2011-01-21 10:50:00+00:00                   0.0
# 52 2011-01-22 06:35:00+00:00 2011-01-22 06:35:00+00:00                   0.0
# 53 2011-01-22 14:08:00+00:00 2011-01-22 14:09:00+00:00                   1.0
# 54 2011-01-23 05:30:00+00:00 2011-01-23 05:48:00+00:00                  18.0
# 55 2011-01-23 18:48:00+00:00 2011-01-23 18:48:00+00:00                   0.0
# 56 2011-01-24 04:31:00+00:00 2011-01-24 04:48:00+00:00                  17.0
# 57 2011-01-24 04:48:00+00:00 2011-01-24 04:48:00+00:00                   0.0
# 58 2011-01-24 14:18:00+00:00 2011-01-24 14:19:00+00:00                   1.0
# 59 2011-01-24 16:54:00+00:00 2011-01-24 17:35:00+00:00                  41.0
#
#     overlap_flag
# 0           True
# 1           True
# 2          False
# 3          False
# 4          False
# 5          False
# 6           True
# 7           True
# 8          False
# 9          False
# 10          True
# 11          True
# 12         False
# 13         False
# 14          True
# 15          True
# 16         False
# 17         False
# 18         False
# 19          True
# 20          True
# 21         False
# 22          True
# 23          True
# 24          True
# 25          True
# 26         False
# 27         False
# 28          True
# 29          True
# 30          True
# 31          True
# 32         False
# 33         False
# 34          True
# 35          True
# 36         False
# 37         False
# 38         False
# 39         False
# 40          True
# 41          True
# 42         False
# 43         False
# 44          True
# 45          True
# 46          True
# 47          True
# 48         False
# 49         False
# 50         False
# 51         False
# 52         False
# 53         False
# 54         False
# 55         False
# 56         False
# 57         False
# 58         False
# 59          True

# %%
from pm4py.objects.log.exporter.xes import exporter as xes_exporter
output_path = 'MR_0.9.xes'

xes_exporter.apply(out, output_path)
print(f"Multitasking execution log saved as {output_path}")
# Out:
# exporting log, completed traces ::   0%|          | 0/608 [00:00<?, ?it/s]
# Multitasking execution log saved as MR_0.9.xes
